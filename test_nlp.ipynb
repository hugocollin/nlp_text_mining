# %%
import pandas as pd

# %%
df =pd.read_csv('data/scrapping/Le Vieux Lyon_reviews.csv')

# %%
df
# Out:
#      Unnamed: 0        user      user_profile       date_review  \
# 0             0    lbcb2023          lbcb2023    5 janvier 2025
# 1             1     ALAIN L         ALAINL623  29 décembre 2024
# 2             2         moi      maryselaloux  24 décembre 2024
# 3             3  Philippe M  W4043LKphilippem  18 décembre 2024
# 4             4     Loops J            l00psj  14 décembre 2024
# ..          ...         ...               ...               ...
# 775         775   Claudia B   V6585NQclaudiab   5 novembre 2016
# 776         776    Muriel P        752murielp   4 novembre 2016
# 777         777   Natacha B       natachab927   25 octobre 2016
# 778         778      Loïc D          lo_cd778   16 octobre 2016
# 779         779      357518            357518   13 octobre 2016
#
#                                                 title  rating type_visit  \
# 0                                             Dommage     2.0    friends
# ...

# %%
df2 =pd.read_csv('data/avis_restaurants_cleaned_tfidf.csv')

# %%
df2
# Out:
#                   user      user_profile date_review  \
# 0               Fred S      fredsX5996LQ  2024-12-15
# 1     Guide38409630404  Guide38409630404  2024-11-27
# 2            Chartin M          chartinm  2024-11-20
# 3         Axelfoley009      Axelfoley009  2024-11-18
# 4             Karine P     karinepU103AS  2024-11-13
# ...                ...               ...         ...
# 4120          Muriel P        752murielp  2016-11-04
# 4121         Natacha B       natachab927  2016-10-25
# 4122            Loïc D          lo_cd778  2016-10-16
# 4123            357518            357518  2016-10-13
# 4124       Gilles74160       Gilles74160  2016-10-10
#
#                                         title  rating type_visit  \
# 0                       Très belle expérience     5.0     family
# 1        Déjeuner au Frazarin, que du bonheur     5.0    friends
# 2               La perfection tout simplement     5.0    couples
# ...
